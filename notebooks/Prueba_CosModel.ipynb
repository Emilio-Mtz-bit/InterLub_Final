# %%
import numpy as np
import pandas as pd
import os
import sys


scripts_path = os.path.join(os.path.abspath('..'), 'scripts')
if scripts_path not in sys.path:
    sys.path.append(scripts_path)
from Cos_Model import Cos_Model

# %%
data = data = pd.read_csv('../data/datos_onehotenocder.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 52 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   idDatosGrasas                              51 non-null     int64
#  1   codigoGrasa                                51 non-null     object
#  2   Grado NLGI Consistencia                    51 non-null     float64
#  3   Viscosidad del Aceite Base a 40°C. cSt     50 non-null     float64
#  4   Penetración de Cono a 25°C, 0.1mm          51 non-null     int64
#  5   Punto de Gota, °C                          51 non-null     int64
#  6   Estabilidad Mecánica, %                    48 non-null     float64
#  7   Punto de Soldadura Cuatro Bolas, kgf       50 non-null     float64
#  8   Desgaste Cuatro Bolas, mm                  27 non-null     float64
#  9   Indice de Carga-Desgaste                   10 non-null     float64
# ...

# %%
data.columns
# Out:
# Index(['idDatosGrasas', 'codigoGrasa', 'Grado NLGI Consistencia',
#        'Viscosidad del Aceite Base a 40°C. cSt',
#        'Penetración de Cono a 25°C, 0.1mm', 'Punto de Gota, °C',
#        'Estabilidad Mecánica, %', 'Punto de Soldadura Cuatro Bolas, kgf',
#        'Desgaste Cuatro Bolas, mm', 'Indice de Carga-Desgaste',
#        'Carga Timken Ok, lb', 'Resistencia al Lavado por Agua a 80°C, %',
#        'Corrosión al Cobre', 'Registro NSF', 'Factor de Velocidad',
#        'Temperatura de Servicio °C, min', 'Temperatura de Servicio °C, max',
#        'categoria', 'subtitulo', 'descripcion', 'beneficios', 'aplicaciones',
#        'color_Ambar', 'color_Beige', 'color_Beige Claro', 'color_Blanco',
#        'color_CafÃ©', 'color_CafÃ© Claro', 'color_Cristalino', 'color_Negro',
#        'color_nan', 'Aceite Base_Mineral', 'Aceite Base_Mineral HC',
#        'Aceite Base_Mineral HT', 'Aceite Base_Mineral Refinado',
#        'Aceite Base_Mineral USP', 'Aceite Base_Semi-Sintetico',
# ...

# %%
drop_columns = ['idDatosGrasas', 'codigoGrasa','categoria', 'subtitulo', 'descripcion', 'beneficios', 'aplicaciones','Corrosión al Cobre']
final_data = data.drop(columns=drop_columns)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 44 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Grado NLGI Consistencia                    51 non-null     float64
#  1   Viscosidad del Aceite Base a 40°C. cSt     50 non-null     float64
#  2   Penetración de Cono a 25°C, 0.1mm          51 non-null     int64
#  3   Punto de Gota, °C                          51 non-null     int64
#  4   Estabilidad Mecánica, %                    48 non-null     float64
#  5   Punto de Soldadura Cuatro Bolas, kgf       50 non-null     float64
#  6   Desgaste Cuatro Bolas, mm                  27 non-null     float64
#  7   Indice de Carga-Desgaste                   10 non-null     float64
#  8   Carga Timken Ok, lb                        46 non-null     float64
#  9   Resistencia al Lavado por Agua a 80°C, %   44 non-null     float64
# ...

# %%
data_numpy = final_data.to_numpy()
example_vector = data_numpy[1]
print(example_vector)
# Out:
# [ 1.50e+00  4.60e+02  3.00e+02  3.04e+02  2.60e+00  9.00e+02  5.00e-01
#   1.66e+02  7.00e+01  3.00e+00       nan  3.00e+05 -3.00e+01  1.50e+02
#   0.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00  0.00e+00
#   1.00e+00  0.00e+00  0.00e+00  0.00e+00  1.00e+00  0.00e+00  0.00e+00
#   0.00e+00  0.00e+00  0.00e+00  1.00e+00  0.00e+00  0.00e+00  0.00e+00
#   0.00e+00  0.00e+00  0.00e+00  1.00e+00  0.00e+00  0.00e+00  0.00e+00
#   0.00e+00  0.00e+00]

# %%
idx_rank, scores_rank, idx= Cos_Model(final_data, example_vector)

# %%
print(idx_rank)
# Out:
# [ 1 42  9  8 10]

# %%
data['codigoGrasa'].iloc[idx_rank]
# Out:
# 1      Grasa_2
# 42    Grasa_42
# 9     Grasa_10
# 8      Grasa_9
# 10    Grasa_11
# Name: codigoGrasa, dtype: object
